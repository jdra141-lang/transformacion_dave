# %% [markdown]
# # ¡Hola Jaime! <a class="tocSkip"></a>
#
# Mi nombre es Oscar Flores y tengo el gusto de revisar tu proyecto. Si tienes algún comentario que quieras agregar en tus respuestas te puedes referir a mi como Oscar, no hay problema que me trates de tú.
#
# Si veo un error en la primera revisión solamente lo señalaré y dejaré que tú encuentres de qué se trata y cómo arreglarlo. Debo prepararte para que te desempeñes como especialista en Data, en un trabajo real, el responsable a cargo tuyo hará lo mismo. Si aún tienes dificultades para resolver esta tarea, te daré indicaciones más precisas en una siguiente iteración.
#
# Te dejaré mis comentarios más abajo - **por favor, no los muevas, modifiques o borres**
#
# Comenzaré mis comentarios con un resumen de los puntos que están bien, aquellos que debes corregir y aquellos que puedes mejorar. Luego deberás revisar todo el notebook para leer mis comentarios, los cuales estarán en rectángulos de color verde, amarillo o rojo como siguen:
#
# <div class='alert alert-block alert-success'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Muy bien! Toda la respuesta fue lograda satisfactoriamente.
# </div>
#
# <div class='alert alert-block alert-warning'>
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Existen detalles a mejorar. Existen recomendaciones.
# </div>
#
# <div class='alert alert-block alert-danger'>
#
# <b>Comentario de Reviewer</b> <a class='tocSkip'></a>
#
# Se necesitan correcciones en el bloque. El trabajo no puede ser aceptado con comentarios en rojo sin solucionar.
# </div>
#
# Cualquier comentario que quieras agregar entre iteraciones de revisión lo puedes hacer de la siguiente manera:
#
# <div class='alert alert-block alert-info'>
# <b>Respuesta estudiante.</b> <a class='tocSkip'></a>
# </div>
#
# Mucho éxito en el proyecto!

# %% [markdown]
# ## Resumen de la revisión v1 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Hola Jaime, ¿cómo va todo? Espero que estés teniendo una buena jornada.
#
# Buen trabajo completando todos los puntos del notebook. El proyecto en general está bien logrado, con una correcta implementación del código necesario. Solo falta completar la sección C4 y agregar conclusiones finales. Te dejé anotaciones en rojo con observaciones puntuales para que puedas hacer esos ajustes.
#
# Ante cualquier duda, no dudes en dejar un comentario en azul. Con gusto lo atenderé en la próxima iteración.
#
# Saludos!
#
#
# </div>

# %% [markdown]
# ## Resumen de la revisión v2 <a class="tocSkip"></a>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor  v2 </b> <a class="tocSkip"></a>
#
# ¡Buen trabajo Jaime! Las últimas correcciones quedaron muy bien. Completaste todas las tareas del notebook de forma correcta, así que no tengo más observaciones que hacer. El proyecto está aprobado. Todo lo que aplicaste aquí será de gran valor en futuros análisis. ¡Mucho éxito en lo que viene!
#
# Saludos.
#
# </div>

# %% [markdown]
# ----

# %% [markdown]
# # ¡Llena ese carrito!

# %% [markdown]
# # Introducción
#
# Instacart es una plataforma de entregas de comestibles donde la clientela puede registrar un pedido y hacer que se lo entreguen, similar a Uber Eats y Door Dash.
# El conjunto de datos que te hemos proporcionado tiene modificaciones del original. Redujimos el tamaño del conjunto para que tus cálculos se hicieran más rápido e introdujimos valores ausentes y duplicados. Tuvimos cuidado de conservar las distribuciones de los datos originales cuando hicimos los cambios.
#
# Debes completar tres pasos. Para cada uno de ellos, escribe una breve introducción que refleje con claridad cómo pretendes resolver cada paso, y escribe párrafos explicatorios que justifiquen tus decisiones al tiempo que avanzas en tu solución.  También escribe una conclusión que resuma tus hallazgos y elecciones.

# %% [markdown]
# ## Diccionario de datos
#
# Hay cinco tablas en el conjunto de datos, y tendrás que usarlas todas para hacer el preprocesamiento de datos y el análisis exploratorio de datos. A continuación se muestra un diccionario de datos que enumera las columnas de cada tabla y describe los datos que contienen.
#
# - `instacart_orders.csv`: cada fila corresponde a un pedido en la aplicación Instacart.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'user_id'`: número de ID que identifica de manera única la cuenta de cada cliente.
#     - `'order_number'`: el número de veces que este cliente ha hecho un pedido.
#     - `'order_dow'`: día de la semana en que se hizo el pedido (0 si es domingo).
#     - `'order_hour_of_day'`: hora del día en que se hizo el pedido.
#     - `'days_since_prior_order'`: número de días transcurridos desde que este cliente hizo su pedido anterior.
# - `products.csv`: cada fila corresponde a un producto único que pueden comprar los clientes.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'product_name'`: nombre del producto.
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
# - `order_products.csv`: cada fila corresponde a un artículo pedido en un pedido.
#     - `'order_id'`: número de ID que identifica de manera única cada pedido.
#     - `'product_id'`: número ID que identifica de manera única cada producto.
#     - `'add_to_cart_order'`: el orden secuencial en el que se añadió cada artículo en el carrito.
#     - `'reordered'`: 0 si el cliente nunca ha pedido este producto antes, 1 si lo ha pedido.
# - `aisles.csv`
#     - `'aisle_id'`: número ID que identifica de manera única cada categoría de pasillo de víveres.
#     - `'aisle'`: nombre del pasillo.
# - `departments.csv`
#     - `'department_id'`: número ID que identifica de manera única cada departamento de víveres.
#     - `'department'`: nombre del departamento.

# %% [markdown]
# # Paso 1. Descripción de los datos
#
# Lee los archivos de datos (`/datasets/instacart_orders.csv`, `/datasets/products.csv`, `/datasets/aisles.csv`, `/datasets/departments.csv` y `/datasets/order_products.csv`) con `pd.read_csv()` usando los parámetros adecuados para leer los datos correctamente. Verifica la información para cada DataFrame creado.

# %% [markdown]
# ## Plan de solución
#
# 1. Primero debemos importar las 5 tablas de datos

# %%
# importar librerías
import pandas as pd
from datetime import datetime
from matplotlib import pyplot as ptl

# %%
df_instacart = pd.read_csv('/datasets/instacart_orders.csv', sep=';')
df_products = pd.read_csv('/datasets/products.csv', sep=';')
df_aisles = pd.read_csv('/datasets/aisles.csv', sep=';')
df_departments = pd.read_csv('/datasets/departments.csv', sep=';')
df_order_products = pd.read_csv('/datasets/order_products.csv', sep=';')

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor         </b> <a class="tocSkip"></a>
#
# Correcto. Bien hecho al importar la data usando el parámetro `sep=;"` para que la lectura de los datos se pueda realizar correctamente.
#
#
# </div>

# %%
# mostrar información del DataFrame
df_instacart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 478967 entries, 0 to 478966
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                478967 non-null  int64
#  1   user_id                 478967 non-null  int64
#  2   order_number            478967 non-null  int64
#  3   order_dow               478967 non-null  int64
#  4   order_hour_of_day       478967 non-null  int64
#  5   days_since_prior_order  450148 non-null  float64
# dtypes: float64(1), int64(5)
# memory usage: 21.9 MB

# %%
# mostrar información del DataFrame
df_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49694 entries, 0 to 49693
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     49694 non-null  int64
#  1   product_name   48436 non-null  object
#  2   aisle_id       49694 non-null  int64
#  3   department_id  49694 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
# mostrar información del DataFrame
df_aisles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 134 entries, 0 to 133
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   aisle_id  134 non-null    int64
#  1   aisle     134 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 2.2+ KB

# %%
# mostrar información del DataFrame
df_departments.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   department_id  21 non-null     int64
#  1   department     21 non-null     object
# dtypes: int64(1), object(1)
# memory usage: 464.0+ bytes

# %%
# mostrar información del DataFrame
df_order_products.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4545007 entries, 0 to 4545006
# Data columns (total 4 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   order_id           4545007 non-null  int64
#  1   product_id         4545007 non-null  int64
#  2   add_to_cart_order  4544171 non-null  float64
#  3   reordered          4545007 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 138.7 MB

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Correcto, muy bien con el uso de `info()` para revisar las filas de los dataframes. Haces bien en utilizar el parámetro `show_counts=True`, ya que si no se pone esto y el dataframe es muy grande, no se mostrará el detalle de todas las filas.
#
#
# </div>

# %%
df_instacart.head()
# Out:
#    order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0   1515936   183418            11          6                 13
# 1   1690866   163593             5          5                 12
# 2   1454967    39980             4          5                 19
# 3   1768857    82516            56          0                 20
# 4   3007858   196724             2          4                 12
#
#    days_since_prior_order
# 0                    30.0
# 1                     9.0
# 2                     2.0
# 3                    10.0
# 4                    17.0

# %%
df_products.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id
# 0             19
# 1             13
# 2              7
# 3              1
# 4             13

# %%
df_aisles.head()
# Out:
#    aisle_id                       aisle
# 0         1       prepared soups salads
# 1         2           specialty cheeses
# 2         3         energy granola bars
# 3         4               instant foods
# 4         5  marinades meat preparation

# %%
df_departments.head()
# Out:
#    department_id department
# 0              1     frozen
# 1              2      other
# 2              3     bakery
# 3              4    produce
# 4              5    alcohol

# %%
df_order_products.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered
# 0   2141543       11440               17.0          0
# 1    567889        1560                1.0          1
# 2   2261212       26683                1.0          1
# 3    491251        8670               35.0          1
# 4   2571142        1940                5.0          1

# %%
# leer conjuntos de datos en los DataFrames
df_instacart.describe()
# Out:
#            order_id        user_id   order_number      order_dow  \
# count  4.789670e+05  478967.000000  478967.000000  478967.000000
# mean   1.709947e+06  102966.537475      17.157808       2.775058
# std    9.869480e+05   59525.328991      17.704688       2.045869
# min    4.000000e+00       2.000000       1.000000       0.000000
# 25%    8.564685e+05   51414.000000       5.000000       1.000000
# 50%    1.709522e+06  102633.000000      11.000000       3.000000
# 75%    2.562990e+06  154419.000000      23.000000       5.000000
# max    3.421079e+06  206209.000000     100.000000       6.000000
#
#        order_hour_of_day  days_since_prior_order
# count      478967.000000           450148.000000
# mean           13.446676               11.101751
# std             4.224986                9.189975
# min             0.000000                0.000000
# 25%            10.000000                4.000000
# 50%            13.000000                7.000000
# ...

# %%
df_products.describe()
# Out:
#          product_id      aisle_id  department_id
# count  49694.000000  49694.000000   49694.000000
# mean   24847.500000     67.773192      11.728478
# std    14345.566475     38.317265       5.850314
# min        1.000000      1.000000       1.000000
# 25%    12424.250000     35.000000       7.000000
# 50%    24847.500000     69.000000      13.000000
# 75%    37270.750000    100.000000      17.000000
# max    49694.000000    134.000000      21.000000

# %%
df_aisles.describe()
# Out:
#          aisle_id
# count  134.000000
# mean    67.500000
# std     38.826537
# min      1.000000
# 25%     34.250000
# 50%     67.500000
# 75%    100.750000
# max    134.000000

# %%
df_departments.describe()
# Out:
#        department_id
# count      21.000000
# mean       11.000000
# std         6.204837
# min         1.000000
# 25%         6.000000
# 50%        11.000000
# 75%        16.000000
# max        21.000000

# %%
df_order_products.describe()
# Out:
#            order_id    product_id  add_to_cart_order     reordered
# count  4.545007e+06  4.545007e+06       4.544171e+06  4.545007e+06
# mean   1.711166e+06  2.558084e+04       8.351669e+00  5.905025e-01
# std    9.850955e+05  1.409552e+04       7.080368e+00  4.917411e-01
# min    4.000000e+00  1.000000e+00       1.000000e+00  0.000000e+00
# 25%    8.608170e+05  1.353500e+04       3.000000e+00  0.000000e+00
# 50%    1.711530e+06  2.527200e+04       6.000000e+00  1.000000e+00
# 75%    2.561311e+06  3.793500e+04       1.100000e+01  1.000000e+00
# max    3.421079e+06  4.969400e+04       6.400000e+01  1.000000e+00

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Muy bien con la revisión también a través del uso de `head()` y `describe()`
#
#
# </div>

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 1. Descripción de los datos.
# Todos los Datos son string y necesitamos que algunos sean int o float o datetime, todos los data frame tienen 1 solo columna, en el primer data frame parece haber un faltante de 15 datos.

# %% [markdown]
# # Paso 2. Preprocesamiento de los datos
#
# Preprocesa los datos de la siguiente manera:
#
# - Verifica y corrige los tipos de datos (por ejemplo, asegúrate de que las columnas de ID sean números enteros).
# - Identifica y completa los valores ausentes.
# - Identifica y elimina los valores duplicados.
#
# Asegúrate de explicar qué tipos de valores ausentes y duplicados encontraste, cómo los completaste o eliminaste y por qué usaste esos métodos. ¿Por qué crees que estos valores ausentes y duplicados pueden haber estado presentes en el conjunto de datos?

# %% [markdown]
# ## Plan de solución
#
# Escribe aquí tu plan para el Paso 2. Preprocesamiento de los datos.
# primero tendremos que seperar por columnas las bases de datos para poder realizar el limpiado de datos

# %% [markdown]
# ## Encuentra y elimina los valores duplicados (y describe cómo tomaste tus decisiones).

# %% [markdown]
# ### `orders` data frame

# %%
# Revisa si hay pedidos duplicados
pedidos_dupli = df_instacart['order_id'].duplicated().sum()
print(f"Pedidos duplicados en order_id: {pedidos_dupli}")
# Out:
# Pedidos duplicados en order_id: 15

# %%
df_instacart[df_instacart['order_id'].duplicated()]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 145574    794638    50898            24          3                  2
# 223105   2160484   107525            16          3                  2
# 230807   1918001   188546            14          3                  2
# 266232   1782114   106752             1          3                  2
# 273805   1112182   202304            84          3                  2
# 284038   2845099    31189            11          3                  2
# 311713   1021560    53767             3          3                  2
# 321100    408114    68324             4          3                  2
# 323900   1919531   191501            32          3                  2
# 345917   2232988    82565             1          3                  2
# 371905    391768    57671            19          3                  2
# 394347    467134    63189            21          3                  2
# ...

# %%
df_instacart[df_instacart['order_id'] == 794638]
# Out:
#         order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 99462     794638    50898            24          3                  2
# 145574    794638    50898            24          3                  2
#
#         days_since_prior_order
# 99462                      2.0
# 145574                     2.0

# %% [markdown]
# ¿Tienes líneas duplicadas? Si sí, ¿qué tienen en común?
# Que los 15 pedidos duplicados se hicieron el dia miercoles a las 2 de la mañana, esto nos puede indicar que posiblemente el servidor por algun motivo de reinicio o de actualizacion esta duploicando los pedidos.

# %%
# Basándote en tus hallazgos,
# Verifica todos los pedidos que se hicieron el miércoles a las 2:00 a.m.
colum = ['order_dow', 'order_hour_of_day']
q_string = "order_dow == 3 and order_hour_of_day == 2"
pedidos_verificados = df_instacart.query(q_string)[colum]
pedidos_verificados
# Out:
#         order_dow  order_hour_of_day
# 4838            3                  2
# 5156            3                  2
# 15506           3                  2
# 18420           3                  2
# 24691           3                  2
# ...           ...                ...
# 457013          3                  2
# 458816          3                  2
# 459635          3                  2
# 468324          3                  2
# 477526          3                  2
#
# [121 rows x 2 columns]

# %% [markdown]
# ¿Qué sugiere este resultado? que ademas de los 15 pedidos duplicados tenemos otros 121 pedidos que se realizaron el mismo dia y misma hora, por algun error de servidor

# %%
# Elimina los pedidos duplicados
df_instacart.drop_duplicates(inplace=True)

# %%
# Vuelve a verificar si hay filas duplicadas
df_instacart[df_instacart.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %%
# Vuelve a verificar únicamente si hay IDs duplicados de pedidos
pedidos_dupli = df_instacart.duplicated(subset='order_id').sum()
print(f"Pedidos duplicados en order_id: {pedidos_dupli}")
# Out:
# Pedidos duplicados en order_id: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos, verificamos dentro del data frame si los 15 duploicados realmente lo fueran, al corroborarlo procedi a eliminarlos y verifique tanto filas como order_id ya no estuvieran duplicados.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Reviewer         </b> <a class="tocSkip"></a>
#
# Bien hecho, dado que todos los duplicados coincidian en el horario y día, es probable que se haya debido a un problema momentaneo en el registro de la data. En un entorno profesional, sería importante revisar que este problema no afecte a muchos registros y ver con el área responsable si esto es un problema conocido o no.
# </div>

# %% [markdown]
# ### `products` data frame

# %%
# Verifica si hay filas totalmente duplicadas
print(df_products.duplicated().sum())
df_products[df_products.duplicated()]
# Out:
# 0
# Empty DataFrame
# Columns: [product_id, product_name, aisle_id, department_id]
# Index: []

# %%
# Revisa únicamente si hay ID de productos duplicados
productos_dupli = df_products['product_id'].duplicated().sum()
print(f"Productos duplicados en product_id: {productos_dupli}")
# Out:
# Productos duplicados en product_id: 0

# %%
# Revisa únicamente si hay nombres duplicados de productos (convierte los nombres a letras mayúsculas para compararlos mejor)
df_products['product_name'] = df_products['product_name'].str.upper()
nombres_duplicados = df_products['product_name'].duplicated().sum()
print(f"Nombres de productos duplicados: {nombres_duplicados}")
# Out:
# Nombres de productos duplicados: 1361

# %%
# Revisa si hay nombres duplicados de productos no faltantes
con_1 = df_products['product_name'].str.upper().duplicated()
con_2 = df_products['product_name'].notna()
df_products[con_1 & con_2]
# Out:
#        product_id                                     product_name  aisle_id  \
# 2058         2059                                  BIOTIN 1000 MCG        47
# 5455         5456                 GREEN TEA WITH GINSENG AND HONEY        96
# 5558         5559                           CREAM OF MUSHROOM SOUP        69
# 7558         7559                        CINNAMON ROLLS WITH ICING       105
# 9037         9038                           AMERICAN CHEESE SLICES        21
# ...           ...                                              ...       ...
# 49689       49690                    HIGH PERFORMANCE ENERGY DRINK        64
# 49690       49691                    ORIGINAL PANCAKE & WAFFLE MIX       130
# 49691       49692  ORGANIC INSTANT OATMEAL LIGHT MAPLE BROWN SUGAR       130
# 49692       49693                           SPRING WATER BODY WASH       127
# 49693       49694                          BURRITO- STEAK & CHEESE        38
#
#        department_id
# 2058              11
# ...

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor           </b> <a class="tocSkip"></a>
#
# Muy bien. En este caso, no es anormal encontrar nombres duplicados y no es necesario eliminarlos. Tienen diferente id, por lo tanto, es posible que sean diferentes versiones de un mismo producto.
# </div>

# %% [markdown]
# ### `departments` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_departments.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de departamentos
departments_dupli = df_departments['department_id'].duplicated().sum()
print(f"Departamentos duplicados en department_id: {departments_dupli}")
# Out:
# Departamentos duplicados en department_id: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# ### `aisles` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_aisles.duplicated().sum()
# Out:
# 0

# %%
# Revisa únicamente si hay IDs duplicadas de pasillos
pasillos_dupli = df_aisles['aisle_id'].duplicated().sum()
print(f"Pasillos duplicados en department_id: {pasillos_dupli}")
# Out:
# Pasillos duplicados en department_id: 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# ### `order_products` data frame

# %%
# Revisa si hay filas totalmente duplicadas
df_order_products[df_order_products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [order_id, product_id, add_to_cart_order, reordered]
# Index: []

# %%
# Vuelve a verificar si hay cualquier otro duplicado engañoso
df_order_products[['order_id', 'product_id']].duplicated().sum()
# Out:
# 0

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos. es aceptable que tengamos estos duplicados ya que un producto puede ser ordenado varias veces

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Buen trabajo en esta sección con la revisión de duplicados
#
# </div>

# %% [markdown]
# ## Encuentra y elimina los valores ausentes
#
# Al trabajar con valores duplicados, pudimos observar que también nos falta investigar valores ausentes:
#
# * La columna `'product_name'` de la tabla products.
# * La columna `'days_since_prior_order'` de la tabla orders.
# * La columna `'add_to_cart_order'` de la tabla order_productos.

# %% [markdown]
# ### `products` data frame

# %%
# Encuentra los valores ausentes en la columna 'product_name'
df_products['product_name'].isna().sum()
# Out:
# 1258

# %% [markdown]
# Describe brevemente cuáles son tus hallazgos. dentro de la columna product_name encontramos 1258 valores ausentes, es posible que no se hayan registrado el nombre del producto.

# %%
#  ¿Todos los nombres de productos ausentes están relacionados con el pasillo con ID 100?
productos_nan = df_products[df_products['product_name'].isna() == True]
productos_nan
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38          NaN       100             21
# 71             72          NaN       100             21
# 109           110          NaN       100             21
# 296           297          NaN       100             21
# 416           417          NaN       100             21
# ...           ...          ...       ...            ...
# 49552       49553          NaN       100             21
# 49574       49575          NaN       100             21
# 49640       49641          NaN       100             21
# 49663       49664          NaN       100             21
# 49668       49669          NaN       100             21
#
# [1258 rows x 4 columns]

# %%
productos_nan['aisle_id'].unique()
# Out:
# array([100])

# %%
# ¿Todos los nombres de productos ausentes están relacionados con el departamento con ID 21?
productos_nan['department_id'].unique()
# Out:
# array([21])

# %%
# Usa las tablas department y aisle para revisar los datos del pasillo con ID 100 y el departamento con ID 21.
df_departments[df_departments['department_id'] == 21]
# Out:
#     department_id department
# 20             21    missing

# %%
df_aisles[df_aisles['aisle_id'] == 100]
# Out:
#     aisle_id    aisle
# 99       100  missing

# %%
#Todos los productos que estan asignados al pasillo 100 no cuentan con nombre ingresado, 
#Todos los productos asignados al departamento 21 estan sin asignarles nombre.

# %%
# Completa los nombres de productos ausentes con 'Unknown'
df_products['product_name'] = df_products['product_name'].fillna('Unknown')
products_unk = df_products[df_products['product_name'] == 'Unknown']
products_unk
# Out:
#        product_id product_name  aisle_id  department_id
# 37             38      Unknown       100             21
# 71             72      Unknown       100             21
# 109           110      Unknown       100             21
# 296           297      Unknown       100             21
# 416           417      Unknown       100             21
# ...           ...          ...       ...            ...
# 49552       49553      Unknown       100             21
# 49574       49575      Unknown       100             21
# 49640       49641      Unknown       100             21
# 49663       49664      Unknown       100             21
# 49668       49669      Unknown       100             21
#
# [1258 rows x 4 columns]

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, debe haber sido un error específico al registrar los datos de ese pasillo y departamento
# </div>

# %% [markdown]
# ### `orders` data frame

# %%
#Encuentra los valores ausentes
df_instacart.isna().sum()
# Out:
# order_id                      0
# user_id                       0
# order_number                  0
# order_dow                     0
# order_hour_of_day             0
# days_since_prior_order    28817
# dtype: int64

# %%
# ¿Hay algún valor ausente que no sea el primer pedido del cliente?
con_1_inst = df_instacart['order_number'] != 1
con_2_inst = df_instacart['days_since_prior_order'].isna()
df_instacart[con_1_inst & con_2_inst]
# Out:
# Empty DataFrame
# Columns: [order_id, user_id, order_number, order_dow, order_hour_of_day, days_since_prior_order]
# Index: []

# %% [markdown]
# no hay ningun valor ausente que no sea el primer pedido del cliente

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien, es normal que esas filas tengan nulos, son los primeros pedidos de los clientes, y entonces no hay días desde un pedido anterior porque no existe ese pedido anterior.
#
# </div>

# %% [markdown]
# ### `order_products` data frame

# %%
# Encuentra los valores ausente
df_order_products.isna().sum()
# Out:
# order_id               0
# product_id             0
# add_to_cart_order    836
# reordered              0
# dtype: int64

# %%
# ¿Cuáles son los valores mínimos y máximos en esta columna?
df_order_products['add_to_cart_order'].min(), df_order_products['add_to_cart_order'].max()
# Out:
# (1.0, 64.0)

# %% [markdown]
# concluimos que los productos se piden por lo menos 1 vez y hasta 64 veces

# %%
# Guarda todas las IDs de pedidos que tengan un valor ausente en 'add_to_cart_order'
id_ped_nan = df_order_products[df_order_products['add_to_cart_order'].isna()]['order_id'].unique()
id_ped_nan
# Out:
# array([2449164, 1968313, 2926893, 1717990, 1959075,  844733,   61355,
#         936852,  264710, 1564093,  129627,  293169, 2849370, 1386261,
#        3308010,  903110, 2136777, 3347453, 1888628,  165801, 2094761,
#        1038146, 2997021,  813364, 2256933,  171934, 2409109, 1730767,
#        1169835,  733526,  404157, 3125735,  747668, 1800005, 1961723,
#         871281,  388234, 1648217, 1477139,  102236, 1021563, 1832957,
#        2721963,  678116, 1220886, 1673227, 2999801, 1633337, 2470674,
#        2625444, 1677118, 2479011, 3383594, 1183255, 1713430, 2652650,
#        1598369, 1916118,  854647, 1302315,  888470,  180546, 2621907,
#        1308785, 2729254,    9310, 2170451, 2979697, 1625713, 1529171])

# %%
# ¿Todos los pedidos con valores ausentes tienen más de 64 productos?
pedidos_con_nan = df_order_products[df_order_products['order_id'].isin(id_ped_nan)]
# Agrupa todos los pedidos con datos ausentes por su ID de pedido.
productos_por_pedido = pedidos_con_nan.groupby('order_id')['product_id'].count().sort_values()
#print(pedidos_con_nan)
productos_por_pedido
# Cuenta el número de 'product_id' en cada pedido y revisa el valor mínimo del conteo.
# Out:
# order_id
# 9310        65
# 747668      65
# 1598369     65
# 1677118     65
# 2170451     65
#           ...
# 1959075     98
# 171934     104
# 2136777    108
# 3308010    115
# 61355      127
# Name: product_id, Length: 70, dtype: int64

# %% [raw]
# de acuerdo a los resultados erojados, debido a que tienen datos ausentes todos se organizan en un mismo grupo por eso es que tienen mas de 64 articulos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Bien hecho, es probable que el sistema no permita más de 64 tipos de productos en esa columna, por lo que no guarda nada después
#
# </div>

# %%
# Remplaza los valores ausentes en la columna 'add_to_cart? con 999 y convierte la columna al tipo entero.

df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].fillna(999)
df_order_products['add_to_cart_order'] = df_order_products['add_to_cart_order'].astype('int')
df_order_products
# Out:
#          order_id  product_id  add_to_cart_order  reordered
# 0         2141543       11440                 17          0
# 1          567889        1560                  1          1
# 2         2261212       26683                  1          1
# 3          491251        8670                 35          1
# 4         2571142        1940                  5          1
# ...           ...         ...                ...        ...
# 4545002    577211       15290                 12          1
# 4545003   1219554       21914                  9          0
# 4545004    692640       47766                  4          1
# 4545005    319435         691                  8          1
# 4545006   1398151       28733                  9          0
#
# [4545007 rows x 4 columns]

# %% [markdown]
# Describe brevemente tus hallazgos y lo que hiciste con ellos.

# %% [markdown]
# ## Conclusiones
#
# Escribe aquí tus conclusiones intermedias sobre el Paso 2. Preprocesamiento de los datos

# %% [markdown]
# # Paso 3. Análisis de los datos
#
# Una vez los datos estén procesados y listos, haz el siguiente análisis:

# %% [markdown]
# # [A] Fácil (deben completarse todos para aprobar)
#
# 1. Verifica que los valores en las columnas `'order_hour_of_day'` y `'order_dow'` en la tabla orders sean razonables (es decir, `'order_hour_of_day'` oscile entre 0 y 23 y `'order_dow'` oscile entre 0 y 6).
# 2. Crea un gráfico que muestre el número de personas que hacen pedidos dependiendo de la hora del día.
# 3. Crea un gráfico que muestre qué día de la semana la gente hace sus compras.
# 4. Crea un gráfico que muestre el tiempo que la gente espera hasta hacer su siguiente pedido, y comenta sobre los valores mínimos y máximos.

# %% [markdown]
# ### [A1] Verifica que los valores sean sensibles

# %%
print(f"'order_hour_of_day' min: {df_instacart['order_hour_of_day'].min()}, max: {df_instacart['order_hour_of_day'].max()}")
print(f"'order_dow' min: {df_instacart['order_dow'].min()}, max: {df_instacart['order_dow'].max()}")
# Out:
# 'order_hour_of_day' min: 0, max: 23
# 'order_dow' min: 0, max: 6

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto, muy bien con el cálculo. Ahora estamos seguros que tenemos datos que hacen sentido en estas columnas.
#
# </div>

# %% [markdown]
# ### [A2] Para cada hora del día, ¿cuántas personas hacen órdenes?

# %%
order_counts_by_hour = df_instacart['order_hour_of_day'].value_counts().sort_index()

ptl.figure(figsize=(10, 6))
ptl.bar(order_counts_by_hour.index, order_counts_by_hour.values, color='skyblue')
ptl.title('Ordenes Distribuidas por hora del dia')
ptl.xlabel('Hora del Dia')
ptl.ylabel('Numero de Ordes')
ptl.xticks(order_counts_by_hour.index)
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.show()

# %% [markdown]
# de 35 mil a 40 mil es el mayor numero de clientes que hacen pedidos entre 9 am a 4 pm

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
#
# Bien hecho con este gráfico, se observa que hay pedidos nocturnos y el peak llega a las 10 de la mañana
#
# </div>

# %% [markdown]
# ### [A3] ¿Qué día de la semana compran víveres las personas?

# %%
order_counts_by_day = df_instacart['order_dow'].value_counts().sort_index()

ptl.figure(figsize=(10, 6))
ptl.bar(order_counts_by_day.index, order_counts_by_day.values, color='lightcoral')
ptl.title('Compras por dia de la Semana')
ptl.xlabel('Dia de la semana')
ptl.ylabel('Numero de Ordenes')
ptl.xticks(order_counts_by_day.index)
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.show()

# %% [markdown]
# los dias que la gente mas compra son los domingos y lunes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Correcto el gráfico, se aprecia que el domingo es el día con mayor cantidad de pedidos. Salvo el lunes, el resto de los días son muy parejos.
#
#
#
# </div>

# %% [markdown]
# ### [A4] ¿Cuánto tiempo esperan las personas hasta hacer otro pedido? Comenta sobre los valores mínimos y máximos.

# %%
ptl.figure(figsize=(10, 6))
ptl.hist(df_instacart['days_since_prior_order'], bins=30, color='pink', edgecolor='black')
ptl.title('Tiempo de espera para que las Personas vuelvan a comprar')
ptl.xlabel('Dias desde la primera orden')
ptl.ylabel('Frecuencia')
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.show()

min_days = df_instacart['days_since_prior_order'].min()
max_days = df_instacart['days_since_prior_order'].max()

print(f"Dias minimos desde la primer compra: {min_days}")
print(f"Dias maximos desde la primer compra: {max_days}")
# Out:
# Dias minimos desde la primer compra: 0.0
# Dias maximos desde la primer compra: 30.0

# %% [markdown]
# Las personas compran cada 15 dias aproximandamente

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor        </b> <a class="tocSkip"></a>
#
# Muy bien, el gráfico es correcto. Nota que el tiempo de 30 días es muy alto, esto es sospechoso ya que es el valor más grande que se registra y es anormalmente grande respecto a los valores que vienen justo antes. Probablemente se debe a que el sistema no registra más de 30 días entre compras y todas las que son de más de ese tiempo las guarda como 30.
#
# </div>

# %% [markdown]
# # [B] Intermedio (deben completarse todos para aprobar)
# 1. ¿Existe alguna diferencia entre las distribuciones `'order_hour_of_day'` de los miércoles y los sábados? Traza gráficos de barra de `'order_hour_of_day'` para ambos días en la misma figura y describe las diferencias que observes.
# 2. Grafica la distribución para el número de órdenes que hacen los clientes (es decir, cuántos clientes hicieron solo 1 pedido, cuántos hicieron 2, cuántos 3, y así sucesivamente...).
# 3. ¿Cuáles son los 20 principales productos que se piden con más frecuencia (muestra su identificación y nombre)?

# %% [markdown]
# ### [B1] Diferencia entre miércoles y sábados para  `'order_hour_of_day'`. Traza gráficos de barra para los dos días y describe las diferencias que veas.

# %%
df_miercoles_orders = df_instacart[df_instacart['order_dow'] == 3]
df_sabado_orders = df_instacart[df_instacart['order_dow'] == 6]
ptl.figure(figsize=(12, 7))
ptl.hist(df_miercoles_orders['order_hour_of_day'], bins=24, range=(0, 23), alpha=0.7, color='purple', label='Miercoles', edgecolor='black')
ptl.hist(df_sabado_orders['order_hour_of_day'], bins=24, range=(0, 23), alpha=0.7, color='yellow', label='Sabado', edgecolor='black')
ptl.title('Ordenes distribuidas por hora del Dia (Miercoles vs. Sabado)')
ptl.xlabel('Hora del dia')
ptl.ylabel('Frecuencia')
ptl.xticks(range(0, 24))
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.legend()
ptl.show()

# %% [markdown]
# Los dias sabados de las 10 am a 2 pm es cuando se realizan mas ordenes

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, muy bien con la comparación entre los días
#
# </div>

# %% [markdown]
# ### [B2] ¿Cuál es la distribución para el número de pedidos por cliente?

# %%
customer_order_counts = df_instacart.groupby('user_id')['order_id'].count()
order_frequency = customer_order_counts.value_counts().sort_index()

ptl.figure(figsize=(12, 6))
ptl.bar(order_frequency.index, order_frequency.values, color='skyblue')
ptl.title('Numero de ordenes Distribuuido por Cliente')
ptl.xlabel('Numero de Ordenes')
ptl.ylabel('Numero de Clientes')
ptl.xticks(order_frequency.index)
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.show()

# %% [markdown]
# El numero de ordenes va disminuyendo por cliente, la recompra disminuye

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
# Excelente, muy bien con el resultado. Observamos que la cantidad de pedidos de cliente es decreciente.
#
#
#
# </div>

# %% [markdown]
# ### [B3] ¿Cuáles son los 20 productos más populares (muestra su ID y nombre)?

# %%
conteo_prod = df_order_products['product_id'].value_counts()
top_20_products_id = conteo_prod.head(20).index

detalle_prod_top = df_products[df_products['product_id'].isin(top_20_products_id)][['product_id', 'product_name']]
display(detalle_prod_top)
# Out:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 40705       40706    ORGANIC GRAPE TOMATOES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49682       49683            CUCUMBER KIRBY

# %% [markdown]
# Los productos mas populares son en su mayoria organicos, a los clientes les importa el origen de sus alimentos

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Correcto,  se ve que predominan los productos orgánicos y de uso diario
#
# </div>

# %% [markdown]
# # [C] Difícil (deben completarse todos para aprobar)
#
# 1. ¿Cuántos artículos suelen comprar las personas en un pedido? ¿Cómo es la distribución?
# 2. ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?
# 3. Para cada producto, ¿cuál es la tasa de repetición del pedido (número de repeticiones de pedido/total de pedidos?
# 4. Para cada cliente, ¿qué proporción de los productos que pidió ya los había pedido? Calcula la tasa de repetición de pedido para cada usuario en lugar de para cada producto.
# 5. ¿Cuáles son los 20 principales artículos que la gente pone primero en sus carritos (muestra las IDs de los productos, sus nombres, y el número de veces en que fueron el primer artículo en añadirse al carrito)?

# %% [markdown]
# ### [C1] ¿Cuántos artículos compran normalmente las personas en un pedido? ¿Cómo es la distribución?

# %%
art_por_orden = df_order_products.groupby('order_id')['product_id'].count()
print(art_por_orden.head())
# Out:
# order_id
# 4     13
# 9     15
# 11     5
# 19     3
# 20     8
# Name: product_id, dtype: int64

# %%
art_prom_ord = art_por_orden.mean()
print(f"Numero promedio de articulos por orden: {art_prom_ord:.2f}")
# Out:
# Numero promedio de articulos por orden: 10.10

# %%
ptl.figure(figsize=(12, 6))
ptl.hist(art_por_orden, bins=50, color='silver', edgecolor='black')
ptl.title('Articulos Distribuidos por Orden')
ptl.xlabel('Numero de Articulos')
ptl.ylabel('Frecuencia')
ptl.grid(axis='y', linestyle='--', alpha=0.7)
ptl.show()

# %%
El número total de productos ordenados por cada cliente se calculó exitosamente contando el campo product_id para cada user_id después de combinar los DataFrames necesarios.
El número total de productos reordenados por cada cliente se determinó sumando la columna reordered para cada user_id.
La proporción de reorden para cada cliente se calculó dividiendo el total de productos reordenados entre el total de productos ordenados. En los casos donde no se ordenaron productos, la proporción de reorden se estableció en 0.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, el cálculo realizado no está mal, pero la presentación del resultado no es la óptima. Idealmente hubieses presentado un gráfico.
#
# </div>

# %% [markdown]
# ### [C2] ¿Cuáles son los 20 principales artículos que vuelven a pedirse con mayor frecuencia (muestra sus nombres e IDs de los productos)?

# %%
product_ord = df_order_products[df_order_products['reordered'] == 1]
cuenta_orde = product_ord['product_id'].value_counts()
top_20_product_id_ord = cuenta_orde.head(20).index

det_top_product_orde = df_products[
df_products['product_id'].isin(top_20_product_id_ord)
][['product_id', 'product_name']]

display(det_top_product_orde)
# Out:
#        product_id              product_name
# 5875         5876             ORGANIC LEMON
# 8276         8277  APPLE HONEYCRISP ORGANIC
# 13175       13176    BAG OF ORGANIC BANANAS
# 16796       16797              STRAWBERRIES
# 21136       21137      ORGANIC STRAWBERRIES
# 21902       21903      ORGANIC BABY SPINACH
# 22934       22935      ORGANIC YELLOW ONION
# 24851       24852                    BANANA
# 24963       24964            ORGANIC GARLIC
# 26208       26209                     LIMES
# 27844       27845        ORGANIC WHOLE MILK
# 27965       27966       ORGANIC RASPBERRIES
# 28203       28204        ORGANIC FUJI APPLE
# 39274       39275       ORGANIC BLUEBERRIES
# 45006       45007          ORGANIC ZUCCHINI
# 47208       47209      ORGANIC HASS AVOCADO
# 47625       47626               LARGE LEMON
# 47765       47766           ORGANIC AVOCADO
# 49234       49235       ORGANIC HALF & HALF
# 49682       49683            CUCUMBER KIRBY

# %% [markdown]
# es la misma lista de los articulos mas populares

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Bien hecho, vemos que los productos más pedidos también son los más reordenados
#
# </div>

# %% [markdown]
# ### [C3] Para cada producto, ¿cuál es la proporción de las veces que se pide y que se vuelve a pedir?

# %%
metrica_produc = df_order_products.groupby('product_id').agg(
    ordenes_total=('order_id', 'count'),
    reorde_total=('reordered', 'sum')
)
metrica_produc.head()
# Out:
#             ordenes_total  reorde_total
# product_id
# 1                     280           158
# 2                      11             0
# 3                      42            31
# 4                      49            25
# 7                       2             1

# %%
metrica_produc['reorder_proportion'] = (metrica_produc['reorde_total'] / metrica_produc['ordenes_total']).fillna(0)
metrica_produc.head()
# Out:
#             ordenes_total  reorde_total  reorder_proportion
# product_id
# 1                     280           158            0.564286
# 2                      11             0            0.000000
# 3                      42            31            0.738095
# 4                      49            25            0.510204
# 7                       2             1            0.500000

# %%
final_product_reorder_df = pd.merge(metrica_produc, df_products, on='product_id', how='left')

final_product_reorder_df = final_product_reorder_df[['product_id', 'product_name', 'reorder_proportion']].sort_values(by='reorder_proportion', ascending=False)

display(final_product_reorder_df.head(20))
# Out:
#        product_id                                       product_name  \
# 13453       14721                            BONE STRENGTH TAKE CARE
# 19195       20949                           VANILLA SANDWICH COOKIES
# 6136         6723                                   PALMIERS- PETITE
# 6144         6732                  NATURALLY SPARKLING MINERAL WATER
# 41319       45088  CALIFORNIA DILL POLLEN & GARLIC GOAT CHEESE & ...
# 41310       45078                                       POMEGRANATEA
# 19258       21016       PARCHMENT LINED 8 IN X 3.75 IN X 2.5 IN PANS
# 19248       21005                        PEANUT BUTTER PIE ICE CREAM
# 32273       35192                         CHOCOLATE SOY MILK SINGLES
# 32277       35197  MOCHA CHOCOLATE CHIP  ORGANIC NON-DAIRY FROZEN...
# 6211         6810                        RASPBERRY GOJI PALEO PRINTS
# 41274       45040                                 HEAD LOCK MEGA GEL
# 41269       45035                               COFFEE FLAVOR YOGURT
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Muy bien, correcto el cálculo. Vemos muchos productos con tasa 1, aunque probablemente hay productos que solo se han pedidos 2 veces, la segunda vez es un reorden, y por eso tienen 100% de reorden.
#
# </div>

# %% [markdown]
# Escribe aquí tus conclusiones

# %% [markdown]
# ### [C4] Para cada cliente, ¿qué proporción de sus productos ya los había pedido?

# %%
df_orde_fusi_prod = pd.merge(df_order_products, df_instacart, on='order_id', how='left')
df_orde_fusi_prod.head()
# Out:
#    order_id  product_id  add_to_cart_order  reordered  user_id  order_number  \
# 0   2141543       11440                 17          0    58454            25
# 1    567889        1560                  1          1   129474            16
# 2   2261212       26683                  1          1    47476             5
# 3    491251        8670                 35          1   134505            27
# 4   2571142        1940                  5          1   155995            22
#
#    order_dow  order_hour_of_day  days_since_prior_order
# 0          0                 15                     8.0
# 1          1                 13                    14.0
# 2          6                  9                    13.0
# 3          6                 13                     9.0
# 4          5                 13                     5.0

# %%
total_product_ordena_por_cliente = df_orde_fusi_prod.groupby('user_id')['product_id'].count()
total_product_ordena_por_cliente.head()
# Out:
# user_id
# 2    26
# 4     2
# 5    12
# 6     4
# 7    14
# Name: product_id, dtype: int64

# %%
total_product_reorden_por_cliente = df_orde_fusi_prod.groupby('user_id')['reordered'].sum()
total_product_reorden_por_cliente.head()
# Out:
# user_id
# 2     1
# 4     0
# 5     8
# 6     0
# 7    13
# Name: reordered, dtype: int64

# %%
metrica_cliente_reord = pd.DataFrame({
    'total_ordered': total_product_ordena_por_cliente,
    'total_reordered': total_product_ordena_por_cliente
})

metrica_cliente_reord['reorder_proportion'] = (
    metrica_cliente_reord['total_reordered'] / metrica_cliente_reord['total_ordered']
).fillna(0)

metrica_cliente_reord[['reorder_proportion']].head()
# Out:
#          reorder_proportion
# user_id
# 2                       1.0
# 4                       1.0
# 5                       1.0
# 6                       1.0
# 7                       1.0

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor          </b> <a class="tocSkip"></a>
#
#
# Aquí faltó realizar el cálculo para los usuarios, aunque va bien orientado, tan solo falta la división.
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor    v2      </b> <a class="tocSkip"></a>
#
# Bien hecho, el cálculo es correcto. Tal como ocurre con los artículos, es probable que estos usuarios solo hayan hecho 2 ordenes.
#
#
#
# </div>

# %% [markdown]
# ### [C5] ¿Cuáles son los 20 principales artículos que las personas ponen primero en sus carritos?

# %%
primer_prod_en_carro = df_order_products[df_order_products['add_to_cart_order'] == 1]
cuenta_primer_prod_en_carro = primer_prod_en_carro['product_id'].value_counts()

top_20_first_in_cart_ids = cuenta_primer_prod_en_carro.head(20).index

top_20_first_in_cart_details = df_products[df_products['product_id'].isin(top_20_first_in_cart_ids)][['product_id', 'product_name']]

top_20_first_in_cart_details = pd.merge(
    top_20_first_in_cart_details,
    cuenta_primer_prod_en_carro.head(20).rename('first_add_count'),
    left_on='product_id',
    right_index=True
).sort_values(by='first_add_count', ascending=False)

display(top_20_first_in_cart_details)
# Out:
#        product_id                 product_name  first_add_count
# 24851       24852                       BANANA            15562
# 13175       13176       BAG OF ORGANIC BANANAS            11026
# 27844       27845           ORGANIC WHOLE MILK             4363
# 21136       21137         ORGANIC STRAWBERRIES             3946
# 47208       47209         ORGANIC HASS AVOCADO             3390
# 21902       21903         ORGANIC BABY SPINACH             3336
# 47765       47766              ORGANIC AVOCADO             3044
# 19659       19660                 SPRING WATER             2336
# 16796       16797                 STRAWBERRIES             2308
# 27965       27966          ORGANIC RASPBERRIES             2024
# 44631       44632   SPARKLING WATER GRAPEFRUIT             1914
# 49234       49235          ORGANIC HALF & HALF             1797
# 47625       47626                  LARGE LEMON             1737
# 195           196                         SODA             1733
# ...

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor            </b> <a class="tocSkip"></a>
#
# Buen trabajo. Al parecer los productos orgánicos representan el grueso de ventas en varios aspectos
#
# </div>

# %% [markdown]
# ### Conclusion general del proyecto:

# %%
Conclusiones generales:
Este análisis implicó una exploración exhaustiva de los datos de pedidos de Instacart, abarcando diversos aspectos, desde la carga y limpieza de datos hasta detalles detallados del comportamiento. A continuación se resumen los principales hallazgos e ideas:
Carga de datos e inspección inicial:
Todos los conjuntos de datos (df_instacart, df_products, df_aisles, df_departments, df_order_products) fueron cargados e inspeccionados con éxito.
Se verificaron los tipos de datos y los conteos no nulos, destacando áreas que necesitaban limpieza, especialmente valores faltantes y duplicados.
Limpieza y preprocesamiento de datos:
Pedidos duplicados: Se identificaron 15 pedidos duplicados en df_instacart y posteriormente se eliminaron. Una investigación más profunda reveló que estos duplicados ocurrieron predominantemente el miércoles a las 2:00 de la madrugada, lo que sugiere un posible problema de entrada de datos o de sistema.
Nombres duplicados de productos: Se encontraron 1361 nombres duplicados de productos en df_products tras convertirlos a mayúsculas. Un subconjunto de estos (104 filas) representaba duplicados reales de nombres de productos.
Valores faltantes:
days_since_prior_order en df_instacart: Los valores faltantes se identificaron correctamente como correspondentes al primer pedido de un cliente (order_number = 1).
product_name en df_products: se encontraron 1258 nombres de productos faltantes, todos vinculados a aisle_id 100 y department_id 21, que estaban etiquetados como "faltantes" en sus respectivas tablas. Estos nombres de productos faltantes estaban llenos de 'Desconocido'.
add_to_cart_order en df_order_products: se identificaron 836 valores faltantes. Todos los pedidos con valores de add_to_cart_order faltantes tenían más de 64 productos, algunos con hasta 127 productos. Estos valores faltantes se rellenaron con 999 y la columna se convirtió a tipo entero.
Análisis de patrones de orden:
Comprobaciones de validez: Se validaron las columnas order_hour_of_day (0-23) y order_dow (0-6) y se encontró dentro de rangos razonables.
Distribución de pedidos por hora del día: Se observó un pico claro en la actividad de pedidos durante las horas de la mañana/tarde (aproximadamente de 9 a 17 horas), con menos pedidos durante la noche o madrugada.
Distribución de pedidos por día de la semana: La distribución mostró volúmenes de pedidos variables según los días, siendo el sábado (día 6) y domingo (día 0) los días de compra más concurridos.
Días desde la orden anterior: La columna de days_since_prior_order iba del 0 al 30. Un histograma reveló un pico fuerte alrededor de 7 días (reordenación semanal) y 30 días (reordenación mensual), lo que sugiere ciclos claros de reordenación.
Horarios de pedido miércoles vs. sábado:
Los pedidos del miércoles alcanzaron su pico más marcado entre la mañana y la tarde (de 9 a 13 horas), probablemente reflejando compras rutinarias influenciadas por los horarios de trabajo.
Los pedidos del sábado mostraron un pico más amplio, que se extendió desde última hora de la mañana hasta la tarde (de 10:00 a 16:00), indicando un periodo de compras más relajado y prolongado, típico de un fin de semana.
Ambos días hubo significativamente menos pedidos a primera hora de la mañana, y el sábado comenzó un poco más tarde la actividad de pedidos.
Análisis de comportamiento de productos y clientes:
Distribución de los Recuentos de Pedidos de los Clientes: El análisis mostró que un gran número de clientes realizó solo un pedido, con una frecuencia que disminuía rápidamente a medida que aumentaba el número de pedidos. Esto pone de manifiesto a un segmento significativo de compradores puntuales.
Artículos promedio por pedido: El número medio de artículos por pedido se calculó en aproximadamente 10,10. Un histograma mostró una distribución con alta frecuencia de órdenes menores y una cola larga para órdenes mayores.
Top 20 de los productos más pedidos: Identificó los productos que aparecen con más frecuencia en todos los pedidos, ofreciendo información sobre los artículos populares.
Top 20 de los productos más frecuentemente repedidos: Identificó los productos que se vuelven a pedir con más frecuencia, indicando la fidelidad del cliente y artículos esenciales.
Proporciones de reordenación de productos: Calculó la proporción de pedidos reordenados para cada producto, revelando productos que casi siempre se reordenan (por ejemplo, aquellos con una proporción de 1,0).
Los 20 productos principales añadidos primero al carrito: Identificó primero los productos que los clientes suelen añadir a su carrito, lo que podría indicar artículos básicos o compras impulsivas.
Proporciones de repedidos por parte de clientes: Calculó la proporción de pedidos de reventa para cada cliente, proporcionando una métrica de fidelidad individual.
Perspectivas y próximos pasos:
Marketing dirigido: La distribución de order_hour_of_day y order_dow puede orientar el momento óptimo para las campañas de marketing y el personal.
Segmentación de clientes: La distribución del recuento de pedidos de clientes sugiere segmentos como compradores puntuales y compradores frecuentes. Un análisis adicional podría explorar las características de estos segmentos para estrategias personalizadas.
Estrategia de producto: Los productos con altas proporciones de pedidos o aquellos que se añaden frecuentemente primero en el carrito son fundamentales. Investiga por qué estos artículos funcionan bien (por ejemplo, necesidad, precio, fidelidad a la marca) para informar la colocación de productos, promociones y gestión de inventario.
Predicción de churn: Analizar a clientes con bajas proporciones de repedidos podría ayudar a identificar a quienes están en riesgo de churn, permitiendo esfuerzos proactivos de retención.
Anomalías detalladas: Un análisis más profundo de los pedidos con valores de add_to_cart_order faltantes (todos con >64 productos) podría revelar escenarios o comportamientos específicos del sistema que conducen a estas anomalías.
Análisis temporal: Incorporar days_since_prior_order en un análisis de series temporales podría proporcionar información más dinámica sobre los ciclos de compra de los clientes y predecir los volúmenes futuros de pedidos.
Análisis de cestas: Un análisis más profundo de la coocurrencia de productos (qué productos se compran juntos) podría revelar valiosas oportunidades de venta cruzada.
# Out:
#   Cell In[68], line 1
#     los cientes tienen ya sus productos preferidos, son los mimos productos de los mas pedidos
#         ^
# SyntaxError: invalid syntax

# %% [markdown]
# <div class="alert alert-block alert-danger">
# <b>Comentario de Revisor              </b><a class="tocSkip"></a>
#
# En las conclusiones recuerda mencionar un resumen breve de lo realizado en el proyecto (qué data se analizó, qué se modificó) y además cuáles son los principales hallazgos, qué se encontró de interesante. Sería ideal que incluyeses alguna métrica (porcentaje, cantidad) de lo más relevante.
#
#
#
# </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Comentario de Revisor      v2    </b> <a class="tocSkip"></a>
#
# Muy bien con las conclusiones, hiciste mención de todos los resultados del proyecto. Si bien te felicito por incluir los detalles de los resultados (con sus respectivas métricas), te recomiendo que hagas algo un poco más resumido; no es necesario mencionar todos los resultados sino que solamente los más relevantes.
#
#
#
# </div>
